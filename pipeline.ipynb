# %%
import ds_api

client = ds_api.DeepSeekClient()
client.chat('你好？你是谁呀')
# Out:
# '你好呀！👋 我是DeepSeek，由深度求索公司创造的AI助手。很高兴认识你！\n\n我是一个纯文本模型，擅长回答各种问题、帮助解决问题、进行创作、分析数据等等。虽然我不支持多模态识别（比如直接“看”图片），但你可以上传图片、PDF、Word、Excel等文件，我会读取其中的文字信息来帮你处理。\n\n我的一些特点：\n- **免费使用**，没有收费计划\n- **上下文长度1M**，可以一次性处理超长文本（比如整本《三体》三部曲）\n- **支持联网搜索**（需要手动开启）\n- **支持语音输入**（App端）\n\n有什么我可以帮你的吗？无论是学习、工作还是日常闲聊，我都很乐意陪你聊聊！😊'

# %%
# 人设生成
prompt='请给出8条完全不同的、完整而丰富但贴近普通民众的人设，用以模拟使用AI模型的普通广大用户。需要定义其姓名、性别、年龄、家庭情况、职业、人种、国籍、所在城市、兴趣爱好等等尽可能丰富的内容。单个人设需要包含3部分信息：1.分块的细节人设，以key-value格式列举；2. 约100字左右的核心人设信息；3. 约500字左右的详细人设信息。这些人设中，一半需为中国人，另一半来自其他国家。结果以json_list格式输出。'

result=client.chat(prompt)

# 注，实际生产时人设管线需要专门迭代精修，不会这么简单。

# %%
charactors=[
    {
        "persona_id": 1,
        "detail_profile": {
            "姓名": "王芳",
            "性别": "女",
            "年龄": 34,
            "家庭情况": "已婚，育有一子（7岁），丈夫为中学教师，与公婆同住",
            "职业": "社区医院全科护士",
            "人种": "汉族",
            "国籍": "中国",
            "所在城市": "河南省郑州市金水区",
            "兴趣爱好": "跳广场舞、追国产剧、烘焙简单点心、在拼多多上比价购物、刷短视频",
            "教育背景": "大专（护理专业）",
            "月收入": "约5000元人民币",
            "常用AI场景": "查菜谱、帮孩子写作文、问感冒药用量、听有声小说",
            "性格特点": "热心但有点急躁，相信权威但喜欢吐槽"
        },
        "core_persona": "王芳是一位34岁的社区护士，生活在郑州，与丈夫、儿子和公婆同住。她工作稳定但琐碎，下班后精力多放在孩子和家务上。她使用AI主要是为了省时省力：查菜谱、辅导作业、解决健康小问题。她不太懂技术，但觉得AI挺方便，常对手机说‘小X小X’来唤醒语音助手。",
        "detailed_persona": "王芳是郑州金水区一家社区医院的全科护士，每天要面对大量老年患者和儿童家长，工作重复却需要耐心。她丈夫在附近的初中教物理，收入不高但稳定。儿子今年刚上小学一年级，正是最费心的时候。王芳每天早晨六点起床做早饭，送孩子上学后赶去医院，下午五点下班接孩子，晚上还要辅导作业、陪公婆聊天。她的生活被琐事填满，手机是她为数不多的私人娱乐工具。她喜欢在抖音上看美食教程和广场舞教学，也常在小红书搜‘孩子不爱吃饭怎么办’。她第一次用AI是让语音助手设闹钟，后来发现可以问‘蒸鱼要多久’‘孩子咳嗽能喝蜂蜜吗’，慢慢养成了习惯。她不太分得清‘AI’和‘智能助手’的区别，只觉得‘这个东西挺听话’。她也会用AI写年终总结，虽然改了不少错别字，但觉得省了大功夫。她对AI的期待很实际：别太复杂，别收费，能说人话。",
        "tags": "中国妈妈, 基层医护, 实用主义, 技术小白"
    },
    {
        "persona_id": 2,
        "detail_profile": {
            "姓名": "陈建国",
            "性别": "男",
            "年龄": 62,
            "家庭情况": "丧偶独居，有一女（已婚，定居上海），每周视频通话两次",
            "职业": "退休国企工人（原机械厂钳工）",
            "人种": "汉族",
            "国籍": "中国",
            "所在城市": "辽宁省沈阳市铁西区",
            "兴趣爱好": "下象棋（公园棋摊）、遛鸟、看新闻联播、研究养生偏方、用手机拍花",
            "教育背景": "高中",
            "月收入": "退休金约3800元人民币",
            "常用AI场景": "语音输入问天气、放大手机字体、让AI念新闻、问‘血压高吃什么’",
            "性格特点": "固执但爱学习新东西，嘴硬心软，对新鲜事物又怕又好奇"
        },
        "core_persona": "陈建国是沈阳一位62岁的退休工人，老伴去世后独居。他每天的主要活动是去公园下棋、遛鸟，晚上看新闻。他买了一部大屏智能手机，但很多功能不会用。他接触AI是从语音助手开始的，现在会对着手机问‘明天有雨没’‘红烧肉怎么做’。他觉得AI‘挺神的’，但总担心被骗钱。",
        "detailed_persona": "陈建国在沈阳铁西区的老机械厂干了一辈子钳工，退休后生活突然空了。老伴三年前因脑梗去世，女儿在上海安了家，一年回来一两次。他养了一只画眉鸟，每天提着鸟笼去劳动公园，跟老伙计们下几盘棋，中午回家随便对付一顿。晚上雷打不动看《新闻联播》和天气预报，然后刷一会儿抖音——主要是看老歌翻唱和养生视频。他的手机是女儿去年给换的华为，屏幕大，但他只会用几个基本功能。第一次用语音助手是偶然按出来的，他试着说‘打电话给闺女’，居然通了，从此觉得这东西‘还行’。现在他常对手机说‘今天沈阳啥天气’‘播一段京剧’，偶尔也问‘降压药和感冒药能一起吃吗’——但他不会全信，还会再去问社区医生。他最大的烦恼是手机老是弹出‘清理垃圾’‘免费领红包’，他怕点错，每次都让女儿远程教。他对AI的期待是：别骗我，别让我输密码，声音大一点。",
        "tags": "中国退休工人, 独居老人, 数字适应期, 养生爱好者"
    },
    {
        "persona_id": 3,
        "detail_profile": {
            "姓名": "林小梅",
            "性别": "女",
            "年龄": 22,
            "家庭情况": "未婚，与父母同住，有一弟弟（高中在读）",
            "职业": "大专应届毕业生，正在找工作（意向：文员/客服）",
            "人种": "汉族",
            "国籍": "中国",
            "所在城市": "广东省广州市番禺区",
            "兴趣爱好": "追星（时代少年团）、逛B站、玩乙女游戏、做手账、喝奶茶打卡",
            "教育背景": "大专（商务英语专业）",
            "月收入": "暂无收入，靠父母补贴，兼职月入约1500元",
            "常用AI场景": "用AI写简历、模拟面试、翻译英文邮件、生成二次元头像、让AI写情话",
            "性格特点": "有点社恐但网上话痨，理想主义，容易焦虑，喜欢可爱的东西"
        },
        "core_persona": "林小梅是广州一个22岁的应届大专生，正在找文员工作。她喜欢追星、做手账、逛B站，对未来既期待又迷茫。她常用AI工具帮忙写简历、改自我介绍，甚至让AI模拟面试官。她也用AI来翻译、写小作文、生成头像，觉得AI像一个‘不会嫌弃我的万能朋友’。",
        "detailed_persona": "林小梅在广州番禺区一个普通家庭长大，父母开小超市，弟弟还在读高中。她大专学的是商务英语，但口语一般，考了四级就没再往上考。毕业两个月了，投了三十多份简历，面试了五六家，都没下文。她有点焦虑，但白天还是照常刷手机。她是时代少年团的粉丝，手机壁纸是宋亚轩，B站收藏夹里全是舞台剪辑。她第一次认真用AI是因为要写求职信，在网上搜到‘用ChatGPT写简历’，试了一下，觉得比自己写的通顺多了。后来她开始让AI帮她模拟面试——她输入‘我是应届生，面试行政助理，你问我问题’，AI问了好几个，她对着手机练了好几遍。她还用AI翻译过一家外贸公司的英文邮件，虽然最后没进面试。最近她在玩AI绘画，生成了一组‘二次元自己’，发到小红书获了十几个赞，开心了一整天。她对AI的期待是：免费、好用、最好能懂她的梗。",
        "tags": "中国应届生, 追星女孩, 求职焦虑, AI深度用户"
    },
    {
        "persona_id": 4,
        "detail_profile": {
            "姓名": "赵大伟",
            "性别": "男",
            "年龄": 45,
            "家庭情况": "已婚，育有两女（大女儿15岁，小女儿8岁），妻子在超市当收银员",
            "职业": "外卖配送员（美团骑手）",
            "人种": "汉族",
            "国籍": "中国",
            "所在城市": "北京市朝阳区（租住城中村）",
            "兴趣爱好": "看足球直播（国安队球迷）、喝酒吃花生米、听郭德纲相声、研究电动车改装",
            "教育背景": "初中",
            "月收入": "约8000-10000元人民币（不稳定）",
            "常用AI场景": "用导航规划最优路线、语音转文字发微信、问‘哪里修电动车便宜’、查违章",
            "性格特点": "吃苦耐劳，脾气有点急，对家人温柔，对新科技实用至上"
        },
        "core_persona": "赵大伟是北京一名45岁的外卖骑手，从河北老家来京打拼十年。他每天跑单十二小时，熟悉朝阳区每一条小巷。他用AI主要靠手机上的语音助手和导航软件——问路况、找近道、语音回消息。他不太懂什么是AI，但只要‘能省一分钟’他都愿意学。",
        "detailed_persona": "赵大伟十年前从河北衡水来北京，干过保安、装修工，最后跑起了外卖。他和妻子租在朝阳区一个城中村的隔断间里，大女儿在老家读高中，小女儿在附近民工子弟学校上二年级。他每天上午十点出门，晚上十点收工，午高峰和晚高峰最忙，夏天晒脱皮，冬天冻得手指僵。他的手机是荣耀千元机，屏幕摔裂了也舍不得换。他最常用的功能是导航——不是用百度地图，而是用美团自带的地图，因为‘它知道哪个小区不让进、哪个电梯要刷卡’。他也会用语音助手发微信，因为打字慢。有一次他送单超时，顾客给了差评，他试过让AI写‘道歉短信’，但觉得太文绉绉，最后还是自己发了一条语音。他最近学会用AI查‘电动车电池冬天不耐用怎么办’，得到答案后试了试，觉得‘有点道理’。他不关心AI会不会取代人类，只关心‘明天单多不多’‘这单能不能多赚两块钱’。他对AI的期待是：别费电，别卡顿，最好能告诉他哪个小区保安不凶。",
        "tags": "中国外卖员, 城市打工人, 底层奋斗者, 实用科技用户"
    },
    {
        "persona_id": 5,
        "detail_profile": {
            "姓名": "Raj Patel",
            "性别": "男",
            "年龄": 28,
            "家庭情况": "未婚，与父母和妹妹同住（印度联合家庭）",
            "职业": "IT支持工程师（外包公司）",
            "人种": "南亚裔（印度）",
            "国籍": "印度",
            "所在城市": "印度班加罗尔电子城",
            "兴趣爱好": "板球（狂热粉丝）、看宝莱坞电影、吃街头小吃、研究加密货币、玩手游（PUBG）",
            "教育背景": "本科（计算机科学）",
            "月收入": "约4.5万卢比（约合3800元人民币）",
            "常用AI场景": "用AI写代码片段、调试bug、生成测试用例、学英语口语、查技术文档",
            "性格特点": "聪明但有点拖延，爱开玩笑，对新技术狂热，有点胖但自称‘健康’"
        },
        "core_persona": "Raj是班加罗尔一名28岁的IT支持工程师，住在父母家，每天通勤两小时。他热爱技术，常让AI帮忙写脚本、查错误、甚至生成‘给女朋友的道歉信’。他英语带浓重印度口音，但自信满满。他相信AI会让印度‘下一个硅谷’变成现实。",
        "detailed_persona": "Raj Patel在班加罗尔一家外包IT公司做技术支持，每天处理各种‘打印机不工作’‘邮箱登不上’之类的工单。他毕业于本地一所工程学院，编程水平中等，但特别会用AI工具。他每天至少打开ChatGPT十次：让AI写一个Python脚本来自动化他的报表、解释一段看不懂的Java代码、或者生成单元测试。他也用AI来学英语——他让AI纠正他的语法，甚至模拟美国客户跟他对话。他女朋友是学医的，不太懂技术，有一次吵架后他让AI写了一段‘诚恳又幽默的道歉信’，女朋友笑了，他觉得AI‘简直是大神’。他业余时间研究加密货币，虽然赔过几万卢比，但依然坚信‘下一个牛市会来’。他每周必看板球比赛，支持的队伍是皇家挑战者班加罗尔队。他对AI的期待是：能说印地语，能懂印度式英语口音，最好能帮他预测板球比赛结果。",
        "tags": "印度IT男, 技术狂热, 板球迷, AI重度依赖"
    }]

# %%
# 口语化改写pipeline
# 用于把所有生成的query问题进行拟人化
import random

humanlike_prompt="我这边有一个用户的具体人设信息，与其向AI提问的意图问题。请根据该意图和用户的人设，生成以这个用户的说话口吻会使用的询问方式。"
strict='你必须严格遵循原始意图的所有内容，仅改为接近口语的格式。不要增加、减少或修改意图。'
non_strict='你可以根据用户人设应有的知识水平和说话习惯适当丰富或减少提问内容中的细节信息，增加或减少部分意图。'

def human_like(q,charactor=None,strict_bool=False):
    if charactor==None:
        charactor=random.choice(charactors)['core_persona']
    if strict_bool:
        return client.chat(humanlike_prompt+strict+'\n\n原始意图问题：\n'+q+'\n\n用户人设：\n'+charactor)
    else:
        return client.chat(humanlike_prompt+non_strict+'\n\n原始意图问题：\n'+q+'\n\n用户人设：\n'+charactor)

# %%
# 获取网站主题类型
import requests

sys_prompt='你是一个网页前端设计专家，有着网页前端设计的丰富经验，能够从网页的代码角度判断其核心主题。用户正尝试让你分析不同网站的主题要素、细分领域、用户需求等，以及其是否有明显定制化的设计。你将被给到一个网页的完整html代码，而你需要以json格式{"主题":"xxx","细分领域":"xxx","用户需求":"xxx","定制化设计":"xxx"}返回结果。'

def check_one_site(url):
    res=requests.get(url)
    result=client.chat([{'role':'system','content':sys_prompt},{'role':'user','content':res.text}])
    return result

site_types=[]
sites=['https://www.baidu.com','https://www.taobao.com','https://www.hao123.com/']
for site in sites:
    site_types.append(check_one_site(site))

print(site_types)
# Out:
# ['{"主题":"搜索引擎首页","细分领域":"通用搜索引擎","用户需求":"快速搜索信息、获取新闻、地图、视频、贴吧等服务入口","定制化设计":"整体采用极简风格，以搜索框为核心，顶部提供新闻、hao123、地图等导航链接，底部显示版权信息，整体设计高度标准化，无明显个性化定制元素"}', '```json\n{\n  "主题": "电子商务平台",\n  "细分领域": "综合电商（B2C/C2C）",\n  "用户需求": "在线购物、商品搜索与推荐、促销活动浏览、安全交易保障",\n  "定制化设计": "高度定制化，包含动态广告横幅、个性化商品推荐、用户中心、购物车、直播入口、分类导航等模块"\n}\n```', '{"主题":"上网导航","细分领域":"网址导航与信息聚合","用户需求":"快速访问常用网站、获取实时热搜和新闻资讯、一站式信息聚合","定制化设计":"高度定制化，包含品牌标志、搜索框、天气预报、热搜榜单、网站分类导航、信息流推荐等模块，并集成广告位和个性化皮肤功能"}']

# %%
# 爬虫获取设计网站的产品列表（如https://www.yibaixun.com/solutions/，此处省去，仅人工添加部分结果作为模拟）

['高端奢侈品网站','学校高校单位网站','个人blog网站']

# %%
# s1. 来自真实、设计良好的网站的原本代码
# 爬虫+清洗实际信息为占位信息+获取网站主体类型

# 爬虫与清洗略过
site_infos=[{'code':'网页清洗后实际代码，略过','主题':'电子商务平台',"细分领域":"综合电商（B2C/C2C）","用户需求": "在线购物、商品搜索与推荐、促销活动浏览、安全交易保障","定制化设计": "包含动态广告横幅、个性化商品推荐、用户中心、购物车、直播入口、分类导航等模块"}]
datas=[]
for info in site_infos:
    raw_content=f'''请为我生成一个网站的前端页面模版，主题为{info['主题']}，具体而言是{info['细分领域']}。\n\n我估计我的用户在使用时有如下需求需要再设计途中满足：{info['用户需求']}。\n\n此外我还有一些额外的要求，我希望{info['定制化设计']}'''
    humanlike_content=human_like(raw_content,strict_bool=True)
    datas.append([{'role':'user','content':humanlike_content},{'role':'assistant','content':info['code']}])

# %%
import random
# s2. 通过调整prompt、强调指定的设计要素，让其它设计模型生成的、经评分模型各项评分均为高分的完整网页数据。prompt的问题风格一般取决于集A中发现的低分样例的主要出现模式，要求模型“不要有XX问题”。
topics_types=['搜索引擎首页','电子商务平台','上网导航','高端奢侈品销售','学校高校单位网站','个人blog']

questions=[]
for i in range(10):
    topic=random.choice(topics_types)
    charactor=random.choice(charactors)
    prompt=f'''请扮演一位正在使用AI进行前端设计网站的用户，模拟其向AI提出需求的对话。我将给予你一个完整的人设，和一个网站主题。请根据这一人设，使其提出一个在该主题下、融入了其个人实际可能涉及的具体需要/喜好的网站前端设计需求。
    请注意：1.你应该直接返回用户说话的内容
    2.用户在于AI文本对话，其说话模式总体仍是偏文本的
    3.你不需要引入用户的每一个人设细节，只需要引入其中最可能契合当前主题的。
    4.用户在给出需求时，语言应该是相对简练的。

    # 网站主题：{topic}

    # 用户人设：{charactor['detailed_persona']}'''
    result=client.chat(prompt)
    print(result)
    print('**********')
    questions.append({'主题':topic,'人设':charactor,'question':result})
    # 其实应该有一步问题的清洗和简单验证结构合理性，比较dirty work，略过
# Out:
# 你好，我想做个我们学校社团的网站首页。我是商务英语专业的，想弄一个那种看起来比较专业但又不会太死板的页面，最好带点年轻感。首页需要有社团介绍、活动展示和加入我们这几个板块，颜色不要太花，蓝白为主吧。哦对了，能不能加一个浮动的小窗口，放我们社团的招新群二维码？
# **********
# 帮我设计一个个人博客的首页，风格要简洁、现代，偏深色模式。我是做IT支持的，平时会分享一些用AI工具解决工作问题的经验，比如用ChatGPT写Python脚本、自动处理工单之类的。博客要有个区域展示最新文章，另外我还想加一个“AI工具推荐”的板块，放我常用的工具列表。对了，底部要留个联系方式，因为我偶尔接点外包活儿。配色的话，用深蓝配亮橙，像我支持的板球队RCB那种感觉。
# **********
# 帮我做一个个人博客的首页设计。我平时在IT公司做技术支持，经常要写技术笔记，也喜欢分享板球和加密货币的东西。风格上我比较喜欢简洁、有点科技感，但不要太冷冰冰的。最好能有一个侧边栏，放一些最近的工单吐槽或者AI工具推荐。颜色的话，我支持皇家挑战者班加罗尔队，红色系为主就挺好。对了，最好还能直接嵌入一个ChatGPT对话风格的留言板，方便我和访客互动。
# **********
# 你好，我是林小梅。我想给我们学校做一个那种……比较青春、活泼一点的高校官网，不要那种死板板的蓝白配色。我是商务英语专业的，但我们学院网站太丑了，我想能不能做一个我们外语学院风格的首页？要有那种国际化的感觉，但又不能太正式，最好能放一些学生活动照片、社团招新的板块，还有那种滚动通知栏。对了，顶部导航栏能不能做得像那种短视频平台风格？圆角、带点渐变色那种。我手机里存了好多我们学校晚会的图，想放上去当轮播图。
# **********
# 帮我做一个学校官网风格的网站，但不用太正式，偏年轻化一点。我是应届生，想放一个求职作品集页面，里面要包含我的简历、自我介绍视频、还有几个我做过的商务英语相关的作业项目展示。颜色别太花，但也不要那种死板的蓝白配，最好带点暖色调。首页能放一张我喜欢的偶像照片当背景吗？就宋亚轩的。
# **********
# ...

# %% [markdown]
# （会发现建国师傅这个人设出的结果有点问题。可能人设过于鲜明，被复杂描述污染了。此类人设按说要在精修人设时去掉）

# %%
import json
system_prompt='''你是一位AI 网页前端设计大师。你根据用户的具体需求，定制化地为TA设计网站。

你的回答需以json格式返回，包括回复用户的自然语言和网页代码两部分。格式为{'text':'xxx','code':'xxx'}

在设计过程中，你需要注意以下要点：
1. 使用颜色时主色 ≤ 3 种；色板统一
2. 字体族 ≤ 2；h1-h6 字号层级清晰递减；杜绝"全是同一字号"
3. 恰当使用负空间；不拥挤不空洞；层次感
4. 跳出"AI slop"的模板感，不要使用千篇一律的设计风格'''# 此处应有更多来自专业设计指导的要求

# 注，其实text的内容根本不重要，不会进入训练数据。采用这个格式只是为了保证模型输出是格式稳定的，方便代码处理。

qa_infos=[]

for index,q in enumerate(questions):
    result=client.chat([{'role':'system','content':system_prompt},{'role':'user','content':q['question']}])
    if result.startswith('```'):
        result=result.replace('```','')
    if result.startswith('json'):
        result=result[4:]
    try:
        result=json.loads(result)
    except:
        print(result)
        continue
    open('result/html/'+str(index)+'.html','a',encoding='utf-8').write(result['code'])
    open('result/data.jsonl','a',encoding='utf-8').write(json.dumps({'q':q,'a':result,'html_path':'result/html/'+str(index)+'.html','conversations':[{'role':'user','content':q['question']},{'role':'assistant','content':result['code']}]},ensure_ascii=False)+'\n')
    qa_infos.append({'q':q,'a':result})
# Out:
# {
#   "text": "好的！我为你设计了一个简洁、有科技感但又不失温度的个人博客首页。整体以红色系为主（致敬RCB），侧边栏包含工单吐槽和AI工具推荐，并嵌入了一个ChatGPT风格的留言板。代码已准备好，可直接运行。",
# ...

# %% [markdown]
# # 机器评分

# %%
# 规则化评分
from rule_code import rule_code 
import os

# 如果不做分离，顺序往下
# for index,info in enumerate(qa_infos):
    # rule_info=rule_code.evaluate_all(info['a']['code'])
    # qa_infos[index]['rule_info']=rule_info

# 如果做了各步骤分离，重新读取
for file in os.listdir('result'):
    code=open('result/'+file,'r',encoding='utf-8').read()
    rule_info=rule_code.evaluate_all(code)
    print(rule_info)
    # qa_infos[index]['rule_info']=rule_info
# Out:
# {'overall_score': 0.646, 'dimension_count': 12, 'dimensions': {'contrast_ratio': {'score': 0.706, 'label': '对比度检测（WCAG AA）', 'weight': 1.0, 'layer': 'L1', 'details': {'total_text_elements': 34, 'passed': 24, 'failed': 10}, 'limitation_note': '无法解析 var() CSS 变量、外部样式表；背景图片上的文字可能漏检', 'issues_count': 10, 'issues': []}, 'font_size': {'score': 0.824, 'label': '字号下限（≥12px）', 'weight': 0.8, 'layer': 'L1', 'details': {'total_text_elements': 34, 'passed': 28, 'failed': 6, 'size_distribution': {'12-13px': 6, '≥20px': 5, '16-19px': 9, '10-11px': 6, '14-15px': 8}}, 'limitation_note': '', 'issues_count': 6, 'issues': []}, 'line_height': {'score': 1.0, 'label': '行高下限（≥1.4）', 'weight': 0.8, 'layer': 'L1', 'details': {'total_text_elements': 34, 'passed': 34, 'failed': 0}, 'limitation_note': '', 'issues_count': 0, 'issues': []}, 'semantic_tags': {'score': 0.0, 'label': '语义化标签', 'weight': 0.6, 'layer': 'L1', 'details': {'used_semantic_tags': [], 'missing_critical': ['footer', 'header', 'main', 'nav'], 
# ...

# %% [markdown]
# ↑ 这个代码需要精修。个别阈值和检测思路是不恰当的，此外一些指标低于特定阈值后应该直接被一票否决权而不是只是影响分数。

# %%
# 模型评分
# 正式使用需要复杂、多次的prompt调整，此处仅作简略展示

prompt_list={'配色协调度':'你是一个网页前端设计专家，有着网页前端设计的丰富经验，能够从网页的代码角度判断其配色的协调度。用户正尝试让你分析一个网站的配色是否协调，以1-5分打分表示。你将被给到一个网页的完整html代码，而你需要以json格式{"score":3,"reason":"xxx"}返回结果。',
             'AI slop 模板感':'类上',
             '组件冗余':'你是一个网页前端设计专家，有着网页前端设计的丰富经验，能够从网页的代码角度判断其配色的协调度。用户正尝试让你分析一个网站的组件设计是否冗余，以1-5分打分表示。你将被给到一个网页在设计时所预期的设计目标，以及设计后的完整html代码。而你需要以json格式{"score":3,"reason":"xxx"}返回结果。',
             '整体美学综合':'类上',
             '设计风格简约程度':'类上'}

for info in qa_infos:
    for key,value in prompt_list.items():
        if key in ['配色协调度','AI slop 模板感']:
            result=client.chat([{'role':'system','content':value},{'role':'user','content':info['a']['code']}])
        else:
            result=client.chat([{'role':'system','content':value},{'role':'user','content':f'''# 网页设计主题\n{info['q']['topic']}\n# 用户具体要求\n{info['q']['question']}\n# 网页实际代码\n{info['a']['code']}'''}])
